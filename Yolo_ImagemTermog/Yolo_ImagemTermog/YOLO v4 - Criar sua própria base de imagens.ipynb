# %% [markdown]
# #YOLO v4 - Criando sua própria base de imagens

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Editando os arquivos de configuração

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15150, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 15150 (delta 37), reused 61 (delta 31), pack-reused 15073
# Receiving objects: 100% (15150/15150), 13.50 MiB | 20.27 MiB/s, done.
# Resolving deltas: 100% (10283/10283), done.

# %%
cd darknet
# Out:
# /content/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:867:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ...

# %% [markdown]
# ##Etapa 7 - Definindo os arquivos de configuração

# %% [markdown]
# ###Modificações no .cfg

# %%
#Copiando o arquivo yolov4 para uma pasta no Google drive
# !cp cfg/yolov4.cfg /content/drive/My\ Drive/Mestrado/2021_1/_-_TE_Intelig_Artificial/Exerc_1_YOLO_PlacasFarois/_YOLOv4/Yolo-PlacasFarois_2/Dataset/yolov4_custom.cfg
#Fazer as alterações no próprio txt do colab

# %% [markdown]
# ###Modificações no obj.names e obj.data

# %%
# !touch obj.names
# !touch obj.data

# %%
# !cp obj.names /content/drive/My\ Drive/Mestrado/2021_1/_-_TE_Intelig_Artificial/Exerc_1_YOLO_PlacasFarois/_YOLOv4/Yolo-PlacasFarois_2/Dataset/obj.names
# !cp obj.data  /content/drive/My\ Drive/Mestrado/2021_1/_-_TE_Intelig_Artificial/Exerc_1_YOLO_PlacasFarois/_YOLOv4/Yolo-PlacasFarois_2/Dataset/obj.data

# %% [markdown]
# ##Etapa 8 - Gerando o arquivo train.txt e test.txt

# %%
pwd
# Out:
# '/content/darknet'

# %%
cd ..
# Out:
# /content

# %%
# !unzip obj.zip -d ./data
# Out:
# Archive:  obj.zip
#    creating: ./data/obj/
#  extracting: ./data/obj/classes.txt
#   inflating: ./data/obj/treino (1).jpg
#   inflating: ./data/obj/treino (1).txt
#   inflating: ./data/obj/treino (10).jpg
#   inflating: ./data/obj/treino (10).txt
#   inflating: ./data/obj/treino (100).jpg
#   inflating: ./data/obj/treino (100).txt
#   inflating: ./data/obj/treino (101).jpg
#   inflating: ./data/obj/treino (101).txt
#   inflating: ./data/obj/treino (102).jpg
#   inflating: ./data/obj/treino (102).txt
#   inflating: ./data/obj/treino (103).jpg
#   inflating: ./data/obj/treino (103).txt
#   inflating: ./data/obj/treino (104).jpg
#   inflating: ./data/obj/treino (104).txt
#   inflating: ./data/obj/treino (105).jpg
#   inflating: ./data/obj/treino (105).txt
#   inflating: ./data/obj/treino (106).jpg
#   inflating: ./data/obj/treino (106).txt
#   inflating: ./data/obj/treino (107).jpg
#   inflating: ./data/obj/treino (107).txt
#   inflating: ./data/obj/treino (108).jpg
# ...

# %%
# !unzip valid.zip -d ./data
# Out:
# Archive:  valid.zip
#    creating: ./data/valid/
#  extracting: ./data/valid/classes.txt
#   inflating: ./data/valid/val (1).jpg
#   inflating: ./data/valid/val (1).txt
#   inflating: ./data/valid/val (10).jpg
#   inflating: ./data/valid/val (10).txt
#   inflating: ./data/valid/val (100).jpg
#   inflating: ./data/valid/val (100).txt
#   inflating: ./data/valid/val (11).jpg
#   inflating: ./data/valid/val (11).txt
#   inflating: ./data/valid/val (12).jpg
#   inflating: ./data/valid/val (12).txt
#   inflating: ./data/valid/val (13).jpg
#   inflating: ./data/valid/val (13).txt
#   inflating: ./data/valid/val (14).jpg
#   inflating: ./data/valid/val (14).txt
#   inflating: ./data/valid/val (15).jpg
#   inflating: ./data/valid/val (15).txt
#   inflating: ./data/valid/val (16).jpg
#   inflating: ./data/valid/val (16).txt
#   inflating: ./data/valid/val (17).jpg
#   inflating: ./data/valid/val (17).txt
#   inflating: ./data/valid/val (18).jpg
#   inflating: ./data/valid/val (18).txt
# ...

# %%
# !python /content/drive/My\ Drive/Mestrado/2021_1/_-_TE_Intelig_Artificial/Exerc_1_YOLO_PlacasFarois/_YOLOv4/Yolo-PlacasFarois_2/TreinamentoYOLO/gerar_train.py

# %%
# !python /content/drive/My\ Drive/Mestrado/2021_1/_-_TE_Intelig_Artificial/Exerc_1_YOLO_PlacasFarois/_YOLOv4/Yolo-PlacasFarois_2/TreinamentoYOLO/gerar_test.py

# %%
cd data
# Out:
# /content/data

# %%
pwd
# Out:
# '/content/data'

# %%
# !cp train.txt /content/drive/My\ Drive/Mestrado/2021_1/_-_TE_Intelig_Artificial/Exerc_1_YOLO_PlacasFarois/_YOLOv4/Yolo-PlacasFarois_2/Dataset/train.txt

# %%
# !cp test.txt  /content/drive/My\ Drive/Mestrado/2021_1/_-_TE_Intelig_Artificial/Exerc_1_YOLO_PlacasFarois/_YOLOv4/Yolo-PlacasFarois_2/Dataset/test.txt
